# %%
import pandas as pd
import numpy as np
df=pd.read_csv('/Users/lubna/Desktop/Salaries 22.11.03.csv')
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
print(df.shape)
print(df.dtypes)
# Out:
# (148654, 13)
# Id                    int64
# EmployeeName         object
# JobTitle             object
# BasePay             float64
# OvertimePay         float64
# OtherPay            float64
# Benefits            float64
# TotalPay            float64
# TotalPayBenefits    float64
# Year                  int64
# Notes               float64
# Agency               object
# Status              float64
# dtype: object

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
print("Data summary:")
print("summary any Digital column")
print("SMA for TotalPay", df.iloc[:,3].mean())
print("The smallest salary within TotalPay", df.iloc[:,3].min())
print("The highest salary within TotalPay", df.iloc[:,3].max())
print("How many duplicate items are in this column?", df.iloc[:,3].value_counts().mode())
print("__________________")
print("summary any Column found in characters ")
print("How many duplicate items are in this column?", df.iloc[:,2].mode())
# Out:
# Data summary:
# summary any Digital column
# SMA for TotalPay 0.20814940686229866
# The smallest salary within TotalPay 0.0
# The highest salary within TotalPay 1.0
# How many duplicate items are in this column? 0    1
# Name: count, dtype: int64
# __________________
# summary any Column found in characters
# How many duplicate items are in this column? 0    Transit Operator
# Name: JobTitle, dtype: object

# %%
#
#Because all the values in the column are missing
df=df.drop(df.columns[[10,12,6]], axis=1)
df
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[185], line 3
#       1 #
#       2 #Because all the values in the column are missing
# ----> 3 df=df.drop(df.columns[[10,12,6]], axis=1)
#       4 df
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:5196, in Index.__getitem__(self, key)
#    5193     else:
#    5194         key = np.asarray(key, dtype=bool)
# -> 5196 result = getitem(key)
#    5197 # Because we ruled out integer above, we always get an arraylike here
#    5198 if result.ndim > 1:
#
# IndexError: index 10 is out of bounds for axis 0 with size 10

# %%
df.columns[3]
# Out:
# 'BasePay'

# %% [markdown]
# df.columns[3]

# %%
print("Category Data Encoding:")
from sklearn.preprocessing import MinMaxScaler
m=MinMaxScaler()
df.iloc[:,3]=m.fit_transform(df.iloc[:,3].values.reshape(-1,1))
df.iloc[:,4]=m.fit_transform(df.iloc[:,4].values.reshape(-1,1))
df.iloc[:,5]=m.fit_transform(df.iloc[:,5].values.reshape(-1,1))
df.iloc[:,6]=m.fit_transform(df.iloc[:,6].values.reshape(-1,1))
df.iloc[:,7]=m.fit_transform(df.iloc[:,7].values.reshape(-1,1))

df
# Out:
# Category Data Encoding:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle   BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  0.524595
# 1                      CAPTAIN III (POLICE DEPARTMENT)  0.488766
# 2                      CAPTAIN III (POLICE DEPARTMENT)  0.666493
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC  0.244433
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  0.421260
# ...                                                ...       ...
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df.iloc[:,-1]=le.fit_transform(df.iloc[:,-1])
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle   BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  0.524595
# 1                      CAPTAIN III (POLICE DEPARTMENT)  0.488766
# 2                      CAPTAIN III (POLICE DEPARTMENT)  0.666493
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC  0.244433
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  0.421260
# ...                                                ...       ...
# 148649                                       Custodian  0.000520
# ...

# %%
print("Handling Missing Values:")
df.isna().sum()
# Out:
# Handling Missing Values:
# Id                  0
# EmployeeName        0
# JobTitle            0
# BasePay             0
# OvertimePay         0
# OtherPay            0
# TotalPay            0
# TotalPayBenefits    0
# Year                0
# Agency              0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
df.iloc[:,3]=imp_mean.fit_transform(df.iloc[:,3].values.reshape(-1,1))
df.iloc[:,4]=imp_mean.fit_transform(df.iloc[:,4].values.reshape(-1,1))
df.iloc[:,5]=imp_mean.fit_transform(df.iloc[:,5].values.reshape(-1,1))
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle   BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  0.524595
# 1                      CAPTAIN III (POLICE DEPARTMENT)  0.488766
# 2                      CAPTAIN III (POLICE DEPARTMENT)  0.666493
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC  0.244433
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  0.421260
# ...                                                ...       ...
# 148649                                       Custodian  0.000520
# ...

# %%
df.isna().sum()
# Out:
# Id                  0
# EmployeeName        0
# JobTitle            0
# BasePay             0
# OvertimePay         0
# OtherPay            0
# TotalPay            0
# TotalPayBenefits    0
# Year                0
# Agency              0
# dtype: int64
